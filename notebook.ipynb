# %% [markdown]
# ### Scenariusz A
# (niewykonalny)

# %%
# %run scenario_a_infeasible.py
# Out:
# Quick sanity check:
# Required A lessons: 6
# T1 Tuesday capacity: 5
# WARNING: Model is likely INFEASIBLE because T1 can only teach on Tuesday.
#
#
# Solver status: INFEASIBLE
# No feasible schedule found.

# %% [markdown]
# ### Scenariusz B
# wykonalny

# %%
# %run scenario_b_feasible.py
# Out:
# Quick sanity check:
# Required A lessons: 6
# T1 capacity on allowed days: 10
#
# Solver status: OPTIMAL
#
# Schedule for S1
# Mon Period 1: ---
# Mon Period 2: C in Room_C
# Mon Period 3: ---
# Mon Period 4: ---
# Mon Period 5: ---
# Tue Period 1: D in Room_D
# Tue Period 2: E in Room_E
# Tue Period 3: ---
# Tue Period 4: C in Room_C
# Tue Period 5: A in Room_A
# Wed Period 1: ---
# Wed Period 2: C in Room_C
# Wed Period 3: ---
# Wed Period 4: B in Room_B
# Wed Period 5: A in Room_A
# Thu Period 1: ---
# Thu Period 2: ---
# Thu Period 3: ---
# Thu Period 4: B in Room_B
# Thu Period 5: ---
# Fri Period 1: ---
# Fri Period 2: ---
# Fri Period 3: C in Room_C
# Fri Period 4: ---
# Fri Period 5: C in Room_C
#
# Schedule for S2
# Mon Period 1: ---
# Mon Period 2: D in Room_D
# Mon Period 3: ---
# Mon Period 4: C in Room_C
# Mon Period 5: ---
# Tue Period 1: ---
# Tue Period 2: ---
# Tue Period 3: A in Room_A
# Tue Period 4: ---
# Tue Period 5: C in Room_C
# Wed Period 1: ---
# ...

# %% [markdown]
# ### Legenda wykresu harmonogramu
#
# - S1, S2, S3 - klasy uczniowskie / grupy uczniów
# - A, B, C, D, E - przedmioty
# - Room_A, Room_B, Room_C, Room_D, Room_E - sale, z których każda jest domyślnie przypisana do konkretnego przedmiotu
# - Mon, Tue, Wed, Thu, Fri - dni tygodnia
# - P1, P2, P3, P4, P5 - kolejne sloty lekcyjne w danym dniu

# %% [markdown]
# Założenia (możliwe, że częściowo dopowiedziane przez model):
# - tydzień roboczy składa się z 5 dni
# - każdy dzień ma 5 slotów lekcyjnych (tu by należało doprecyzować z góry)
# - każda klasa uczniowska ma tę samą liczbę zajęć z każdego przedmiotu (tu by należało doprecyzować z góry)
# - każdy przedmiot ma jednego przypisanego nauczyciela
# -dowolny przedmiot może odbywać się w dowolnej sali, ale użycie sali niepreferowanej jest karane w funkcji celu
# - nauczyciel nie może prowadzić dwóch zajęć jednocześnie
# - jedna sala nie może być używana przez więcej niż jedną klasę w tym samym czasie
# - jedna klasa uczniowska nie może mieć dwóch zajęć jednocześnie
#
# Należałoby rozważyć:
# - identyfikowanie ukrytych założeń,
# - zadawanie pytań doprecyzowujących (może w formie chatu?),
# - oddzielanie danych wejściowych od domyślnych założeń modelu,
# - walidacja poprawności interpretacji opisu przed uruchomieniem solvera
